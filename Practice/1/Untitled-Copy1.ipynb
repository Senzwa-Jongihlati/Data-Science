# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("water_potability.csv")

# %%
df.shape
# Out:
# (3276, 10)

# %% [markdown]
# *Data Understanding and EDA*

# %%
df.columns
# Out:
# Index(['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
#        'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %%
import seaborn as sns

# %%
df.hist(figsize=(12, 8))
plt.show()

# %% [markdown]
# Checking missing values based of percentage

# %%
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# ph                 14.987790
# Hardness            0.000000
# Solids              0.000000
# Chloramines         0.000000
# Sulfate            23.840049
# Conductivity        0.000000
# Organic_carbon      0.000000
# Trihalomethanes     4.945055
# Turbidity           0.000000
# Potability          0.000000
# dtype: float64

# %%
df.dropna(inplace=True)

# %%
df.Potability.value_counts()
# Out:
# Potability
# 0    1200
# 1     811
# Name: count, dtype: int64

# %%
potable=df[df["Potability"]==1]
notpotable=df[df["Potability"]==0]

# %% [markdown]
# Importing resampler

# %%
from sklearn.utils import resample
df_minority_upsampled = resample(potable, replace = True, n_samples = 1200)

# %%
from sklearn.utils import shuffle
df = pd.concat([notpotable, df_minority_upsampled])
df = shuffle(df) 

df.shape
df.Potability.value_counts()
# Out:
# Potability
# 0    1200
# 1    1200
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm')
plt.show()

# %%
corr = df.corr()
corr["Potability"].sort_values(ascending=False)*100
# Out:
# Potability         100.000000
# Trihalomethanes      4.674333
# Solids               2.218988
# Chloramines          1.845125
# Sulfate              0.286048
# ph                   0.146098
# Conductivity         0.075398
# Turbidity           -0.102247
# Organic_carbon      -0.386375
# Hardness            -0.604422
# Name: Potability, dtype: float64

# %%
g = sns.FacetGrid(df,col="Potability")
g.map(plt.hist,"Trihalomethanes",bins=25)

# %%
sns.pairplot(df[['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
       'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability']])

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
X = df.drop(["Potability"],axis=1)
y = df["Potability"]

# %%
from sklearn.preprocessing import StandardScaler
st = StandardScaler()
col= X.columns
X[col] = st.fit_transform(X[col])
X[col]
# Out:
#             ph  Hardness    Solids  Chloramines   Sulfate  Conductivity  \
# 1870 -0.318910  0.661205  0.312757    -0.800615 -0.563098      0.597923
# 2350 -1.290829  1.336825  0.771962    -3.538727 -1.828265      0.302251
# 2396  0.422926  0.482971 -0.049026    -0.091988 -1.573706      0.836102
# 1033  0.443726  0.092303 -0.337931     0.146968 -0.413103     -0.724874
# 489  -0.912722 -0.335582 -0.503778    -1.122315  0.125952     -0.222024
# ...        ...       ...       ...          ...       ...           ...
# 378  -0.629714  1.622882  2.751781     0.142951  0.119038     -1.379048
# 1257 -1.021980 -0.952729 -1.158781    -0.207083 -0.767761      1.345663
# 3209 -1.444261  0.809140 -0.722146     0.470217 -0.326455     -0.120115
# 1353  2.916060 -0.381823 -2.079306     0.172149  1.578032      0.583192
# 1775 -0.683339 -0.763110 -1.279140     0.655076 -0.680343      0.994463
#
#       Organic_carbon  Trihalomethanes  Turbidity
# 1870       -0.888062        -1.167225  -0.570927
# 2350       -0.165409         0.284047   0.879348
# 2396       -0.886105         1.139856   1.306233
# 1033       -1.324162        -0.111668  -1.053457
# 489         0.243172        -2.217120  -0.883670
# ...              ...              ...        ...
# 378        -0.942931         1.367781  -1.097087
# 1257        0.001945         0.184669   0.905937
# 3209        0.343767         1.087850   0.015700
# 1353       -1.066821         0.151814  -1.229817
# 1775       -0.644367        -0.256021  -0.368960
#
# [2400 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2)

# %%
model = RandomForestClassifier(max_depth=15)
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=15)

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
cm = confusion_matrix(y_test,y_pred)

print(classification_report(y_test,y_pred))


sns.heatmap(cm,annot=True,fmt="d",cmap="coolwarm")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.84      0.84       239
#            1       0.84      0.85      0.85       241
#
#     accuracy                           0.85       480
#    macro avg       0.85      0.85      0.85       480
# weighted avg       0.85      0.85      0.85       480
# <Axes: >

# %%
train_accuracy = model.score(X_train, y_train)
test_accuracy = model.score(X_test, y_test)

print("Training Accuracy:", train_accuracy)
print("Testing Accuracy:", test_accuracy)
# Out:
# Training Accuracy: 0.9973958333333334
# Testing Accuracy: 0.8541666666666666
